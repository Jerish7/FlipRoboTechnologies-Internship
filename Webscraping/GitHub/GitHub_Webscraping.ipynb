# %%
#Importing required libraries
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import ElementNotInteractableException

# %% [markdown]
# 5.Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#Connect to web driver
driver=webdriver.Chrome(r"D://chromedriver.exe")  #r converts string to raw string
#If not r, we can use executable_path = "C:/path name"

# %%
#Getting the website to driver
driver.get('https://github.com/')

#When we run this line, automatically the webpage will be opened

# %%
#Clicking explore tab and trending option using exception
trending=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a")
try:
    trending.click()
except ElementNotInteractableException as e:
    driver.get(trending.get_attribute('href'))

# %%
#Creating empty lists for storing the scrapped data
rep_title=[]
rep_desc=[]
Count=[]
Lang=[]

#Scrapping the data having the repository title
title=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
for i in title:
    rep_title.append(i.text)
    
#Scrapping the data having the repository description
desc=driver.find_elements_by_xpath("//p[@class='col-9 color-text-secondary my-1 pr-4']")
for i in desc:
    rep_desc.append(i.text)
    
#Scrapping the data having the contributors count
count=driver.find_elements_by_xpath("//div[@class='f6 color-text-secondary mt-2']/a[2]")
for i in count:
    Count.append(i.text)
    
#Scrapping the data having the language used 
lang=driver.find_elements_by_xpath("//span[@class='d-inline-block ml-0 mr-3']")
for i in lang:
    if i.text is None:
        Lang.append('Not Available')
    else:
        Lang.append(i.text)

# %%
#Checking out the length of scrapped data
print(len(rep_title),len(rep_desc),len(Count),len(Lang))
# Out:
# 25 22 25 23

# %%
#Creating a dataframe for the scrapped data
github=pd.DataFrame({})
github['Repository title']=rep_title[:22]
github['Description']=rep_desc
github['Contributors count']=Count[:22]
github['Language used']=Lang[:22]
github
# Out:
#                              Repository title  \
# 0                     facebookresearch / dino
# 1   kelseyhightower / kubernetes-the-hard-way
# 2              Chia-Network / chia-blockchain
# 3                         supabase / supabase
# 4                         bitclout / frontend
# 5        mrdbourke / tensorflow-deep-learning
# 6                         dogecoin / dogecoin
# 7                           thedevdojo / wave
# 8                  DIGITALCRIMINAL / OnlyFans
# 9                        twintproject / twint
# 10              projectdiscovery / interactsh
# 11               androidmalware / android_hid
# 12                        commaai / openpilot
# 13                 TheAlgorithms / Javascript
# 14                Uniswap / uniswap-interface
# 15                     ninjamuffin99 / Funkin
# 16              katherinepeterson / readme.so
# 17                    flashlight / flashlight
# 18                      microsoft / PowerToys
# 19                              github / docs
# 20                       wisz2021 / jd_docker
# 21                  CSSEGISandData / COVID-19
#
#                                           Description Contributors count  \
# 0   PyTorch code for Vision Transformers training ...                 92
# 1   Bootstrap Kubernetes the hard way on Google Cl...              7,954
# 2   Chia blockchain python implementation (full no...                630
# 3   The open source Firebase alternative. Follow t...                453
# 4                               bitclout.com frontend                 28
# 5   All course materials for the Zero to Mastery D...                164
# 6                                       very currency              1,456
# 7   Wave - The Software as a Service Starter Kit, ...                116
# 8   Scrape all the media from an OnlyFans account ...                194
# 9   An advanced Twitter scraping & OSINT tool writ...              1,446
# 10  An OOB interaction gathering server and client...                 10
# 11  Use Android as Rubber Ducky against another An...                142
# 12  openpilot is an open source driver assistance ...              4,961
# 13  A repository for All algorithms implemented in...              1,874
# 14  🦄 An open source interface for the Uniswap pro...              1,574
# 15      A C++ standalone library for machine learning                491
# 16  Windows system utilities to maximize productivity                 70
# 17           The open-source repo for docs.github.com                315
# 18                                             仅用查看文档              2,940
# 19  Novel Coronavirus (COVID-19) Cases, provided b...             16,116
# 20  Script to check the available slots for Covid-...                207
# 21                       RDBMS のしくみを学ぶための小さな RDBMS 実装             16,900
#
#        Language used
# 0             Python
# 1             Python
# 2         TypeScript
# 3         TypeScript
# 4   Jupyter Notebook
# 5                C++
# 6                PHP
# 7             Python
# 8             Python
# 9                 Go
# 10             Shell
# 11               C++
# 12        JavaScript
# 13        TypeScript
# 14              Haxe
# 15        JavaScript
# 16               C++
# 17                C#
# 18        JavaScript
# 19             Shell
# 20        JavaScript
# 21  Jupyter Notebook

# %%
#Closing the driver
driver.close()
